# %% [markdown]
# <a href="https://colab.research.google.com/github/lucken99/DataScience_Notes/blob/main/Apache_Airflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from IPython.display import Image, display

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/MyDrive/DataScience_Notes/Apache_Airflow/"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
def display_sc(image_name, height=None, width=None):
    return display(Image(os.path.join(path, image_name), width=width if width else None, height=height if height else None))

# %% [markdown]
# # [Read the docs](https://airflow.apache.org/docs/apache-airflow/stable/index.html)

# %% [markdown]
# # Apache Airflow

# %%
display(Image(os.path.join(path, "1Airflow.png"), width=700))

# %%
display_sc("1bAirflow.png")

# %% [markdown]
# ## Its Principles

# %%
display_sc("2Airflow.png", width=800, height=300)

# %% [markdown]
# ## Its Features

# %%
display_sc("3Airflow.png")

# %%
display_sc("4Airflow.png")

# %%
display_sc("5Airflow.png")

# %%
display_sc("6Airflow.png")
