# %% [markdown]
# <a href="https://colab.research.google.com/github/lucken99/DataScience_Notes/blob/main/Apache_Spark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #[APACHE SPARK](https://spark.apache.org/docs/latest/quick-start.html)

# %%
import os
from IPython.display import Image, display

# %%
from google.colab import drive
drive.mount('/content/drive')
path = "/content/drive/MyDrive/DataScience_Notes/Apache_Spark/"
# Out:
# Mounted at /content/drive

# %%
def display_sc(image_name, height=None, width=None):
    return display(Image(os.path.join(path, image_name), width=width if width else None, height=height if height else None))

# %%
display_sc("1Spark.png")

# %%
display_sc("2SparkFeatures.png")

# %%
display_sc("3SparkEcosystem.png")

# %%
display_sc("4SparkSQL.png")
